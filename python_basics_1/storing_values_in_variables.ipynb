# %% [markdown]
# variable is like a box in computers memory where you can store a single value. variables reference the objects stored on the heap

# %% [markdown]
# assignment statement = variable name, an equal sign and value stored. eg;

# %%
variable = 69
