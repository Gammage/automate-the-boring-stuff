# %% [markdown]
# using ,, in a number makes it a tuple, parenthesis is optional. samne thing

# %%
tuple_example = 1,00,00,00
tuple_example = (1,00,00,00)

# %%
integer_example = 1000000

# %% [markdown]
# you can loop through a tuple,
# you can index it,
# you can slice

# %%
but a list is changeable

# %%
a = [1,2,3]
print(a[0])
a[0] = 99
print(a[0])
# Out:
# 1
# 99

# %%
a = 1,2,3
print(a[0])
a[0] = 99
print(a[0])
# Out:
# 1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 a = 1,2,3
#       2 print(a[0])
# ----> 3 a[0] = 99
#       4 print(a[0])
#
# TypeError: 'tuple' object does not support item assignment
