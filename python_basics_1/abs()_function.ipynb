# %% [markdown]
# behaviour of rounding numbers can be harsh. round(3.5) rounds up to 4. half way numbers that end with .5, number is rounded to nearest even integer (bankers rounding)

# %% [markdown]
# abs() function returns the absolute value, but just see it as positive form of the number

# %%
abs(-25)

# %% [markdown]
# just see the repl
