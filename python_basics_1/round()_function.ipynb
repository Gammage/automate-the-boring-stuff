# %% [markdown]
# round function accepts a float value and returns the nearest integer

# %%
round(3.14)
# Out:
# 3

# %% [markdown]
# a second parameter rounds to the nearest decimal, in below case by 1

# %%
round(3.14, 1)
# Out:
# 3.1
